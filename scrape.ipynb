# %%
import pandas as pd
import twint
import nest_asyncio

nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Search = '@TheBridge_Tech'
c.Store_csv = True
c.Output = 'data/raw_tweets.csv'
c.Since = '2022-01-01 00:00:00'
c.Hide_output = True
c.Debug = True

# Run
try:
    twint.run.Search(c)
except Exception as e:
    print(e)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
data = pd.read_csv('data/tweets.csv')

# %%
data.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
df = data[['id', 'tweet', 'created_at', 'user_id', 'name', 'username', 'retweets_count', 'replies_count', 'likes_count', 'quote_url']]

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
# Out:
# /tmp/ipykernel_20495/329245698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.to_csv('data/clean_tweets.csv', index=False)

# %%
df = pd.read_csv('data/clean_tweets.csv')
df
# Out:
#                       id                                              tweet  \
# 0    1528696920729956352  Terminando el desafio de tripulaciones en @The...
# 1    1528650844094271490  "El libro de la inteligencia colectiva"   http...
# 2    1528647207594909696  Este jueves nos vemos en @TheBridge_Tech para ...
# 3    1528641426975760389  Conoce las 25 ofertas de #empleo de la empresa...
# 4    1528638307516694529  #LastMinute La 2da presentación del #LibroIC e...
# ..                   ...                                                ...
# 134  1483469787078533123  Del periodismo al marketing digital 🤸 esta es ...
# 135  1481340966866989063  Ciclo de Conferencias sobre Inteligencia Artif...
# 136  1480228635294449667  Me encantaría saber que les enseñan sobre esta...
# 137  1479787660910768132  @cbusquets Hola, @TheBridge_Tech te da la opci...
# 138  1478637395289378817  ¿Quieres formarte en una de las profesiones qu...
#
#                     created_at              user_id                  name  \
# 0    2022-05-23 13:18:42+02:00  1528649918306557952         Nacho Esteban
# 1    2022-05-23 10:15:36+02:00             41545659  Mario Lopez de Avila
# 2    2022-05-23 10:01:09+02:00              4628161           Tíscar Lara
# 3    2022-05-23 09:38:11+02:00            987388686       Juan Luis Pavón
# 4    2022-05-23 09:25:47+02:00             15993641         Amalio A. Rey
# ..                         ...                  ...                   ...
# 134  2022-01-18 17:02:13+01:00  1162694149956603904            The Bridge
# 135  2022-01-12 20:03:03+01:00             41545659  Mario Lopez de Avila
# 136  2022-01-09 18:23:02+01:00            183583012  Ingeniero Titiritero
# 137  2022-01-08 13:10:46+01:00             10045342    Carlos A. Marchena
# 138  2022-01-05 09:00:01+01:00   966573471663828992         PymesMagazine
#
#            username  retweets_count  replies_count  likes_count  \
# 0       nachooatm82               0              0            0
# 1      nodosenlared               2              0            5
# 2            tiscar               0              0            1
# 3    juanluispavon1               2              0            6
# 4              arey               1              0            2
# ..              ...             ...            ...          ...
# 134  thebridge_tech               0              0            0
# 135    nodosenlared               1              0            6
# 136  ing_titiritero               0              0            0
# 137       cmarchena               0              0            4
# 138   pymesmagazine               0              0            3
#
#                                              quote_url
# 0                                                  NaN
# 1                                                  NaN
# 2    https://twitter.com/arey/status/15286383075166...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
#
# [139 rows x 10 columns]
